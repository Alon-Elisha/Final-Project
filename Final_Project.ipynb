# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/alonm/Desktop/projectFiles/winequalityN.csv')

# %%
data.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %% [markdown]
# # inspecting the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %% [markdown]
# 1 - fixed acidity: most acids involved with wine or fixed or nonvolatile (do not evaporate readily)
#
# 2 - volatile acidity: the amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste
#
# 3 - citric acid: found in small quantities, citric acid can add ‘freshness’ and flavor to wines
#
# 4 - residual sugar: the amount of sugar remaining after fermentation stops, it’s rare to find wines with less than 1 gram/liter and wines with greater than 45 grams/liter are considered sweet
#
# 5 - chlorides: the amount of salt in the wine
#
# 6 - free sulfur dioxide: the free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion; it prevents microbial growth and the oxidation of wine
#
# 7 - total sulfur dioxide: amount of free and bound forms of S02; in low concentrations, SO2 is mostly undetectable in wine, but at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine
#
# 8 - density: the density of water is close to that of water depending on the percent alcohol and sugar content
#
# 9 - pH: describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic); most wines are between 3-4 on the pH scale
#
# 10 - sulphates: a wine additive which can contribute to sulfur dioxide gas (S02) levels, wich acts as an antimicrobial and antioxidant
#
# 11 - alcohol: the percent alcohol content of the wine
#
# Output variable (based on sensory data): 12 - quality (score between 0 and 10)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
# printing the unique values of each column to get a better pictute of the dataset
for i in data.columns:
    print(i + ":")
    print(data[i].unique())
    print("")
# Out:
# type:
# ['white' 'red']
#
# fixed acidity:
# [ 7.    6.3   8.1   7.2   6.2   8.6   7.9   6.6   8.3    nan  7.4   6.5
#   6.4   6.8   7.6   6.9   8.5   5.8   7.3   6.7   6.    7.1   6.1   7.5
#   9.8   5.5   5.9   7.8   5.7   8.2   5.6   5.2   8.4  10.2   7.7   5.3
#   5.4   9.1   5.    8.   10.    5.1   9.2   9.    8.8   8.7   4.8  10.3
#   9.4   9.6   9.3   8.9   9.7  10.7  14.2   9.9   9.5  11.8   4.6   6.15
#   4.5   7.15  6.45  4.2   4.9   4.7   3.8   4.4   3.9  11.2  10.1  11.5
#  12.8  11.   11.6  12.   15.   10.8  11.1  12.5  10.9  11.4  10.4  13.3
#  10.6  13.4  11.9  12.4  12.2  13.8  13.5  10.5  12.6  14.   13.7  12.7
#  12.3  15.6  11.3  13.   12.9  14.3  15.5  11.7  13.2  15.9  12.1 ]
#
# volatile acidity:
# [0.27  0.3   0.28  0.23  0.32  0.22  0.18  0.16  0.42  0.17  0.48  0.66
#  0.34  0.31  0.26  0.67  0.25  0.24  0.14  0.12  0.39  0.33  0.45  0.46
#  0.19  0.2   0.21  0.38  0.47  0.35  0.54  0.43  0.44    nan 0.265 0.36
# ...

# %% [markdown]
# # dealing with NaN values

# %%
# seeing if there are NaN values
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
# filling the nan values in the value of mean of the columns.
data['fixed acidity'] = data['fixed acidity'].fillna(data['fixed acidity'].mean())

data['volatile acidity'] = data['volatile acidity'].fillna(data['volatile acidity'].mean())

data['citric acid'] = data['citric acid'].fillna(data['citric acid'].mean())

data['residual sugar'] = data['residual sugar'].fillna(data['residual sugar'].mean())

data['chlorides'] = data['chlorides'].fillna(data['chlorides'].mean())

data['pH'] = data['pH'].fillna(data['pH'].mean())

data['sulphates'] = data['sulphates'].fillna(data['sulphates'].mean())

data.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x = 'quality', y = 'alcohol', data = data)
plt.ylabel('Alcohol')
plt.xlabel('Wine quality')
plt.title('Quality of wine in relation to alcohol');

# %%
# the conclusion from the diagram is that wine with better quality generally have more alcohol in it.

# %%
sns.barplot(x = 'type', y = 'quality', data = data)
plt.ylabel('Wine Quality')
plt.xlabel('Type of wine')
plt.title('Wine quality in relations to the type of wine');

# %%
# it seems that white wine has slightly better quality than red wine generally

# %%
sns.barplot(x=data['quality'].unique(), y=data['quality'].value_counts())
plt.ylabel('Count')
plt.xlabel('Wine quality')
plt.title('Number of wines for each quality category');

# %%
# in conclusion, it seems that there aren't many great wines, and the extremes 1,2 and 10 don't exist.

# %%
#changing the type of variable 'type' is
data['type'] = data['type'].map({'white' : 0, 'red' : 1})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   int64
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
data['quality'] = data['quality'].map({3 : 0, 4: 0, 5 : 0 , 6:0, 7:1, 8:1, 9 : 1})
# we classify the good and bad as good wine - 7 and above, and bad wine - 6 and below.
# we know that 3,4,5,6,7,8,9 are the only qualities in the dataset.

# %%
df = data
sns.countplot(x = 'quality', data = df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# we see that that class 0 - the bad wine class, easily outstrips class 1 - the good wine, in numbers.

# %% [markdown]
# # using models

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score

# %%
clf=RandomForestClassifier(n_estimators=100)

# %%
X = data.drop(['quality'], axis = 1)

# %%
y = data['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %% [markdown]
# # discovering the importance of features

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
feature_imp = pd.Series(clf.feature_importances_, index = X.columns).sort_values(ascending=False)
# multiplying by a hundred to see importance in percentage
feature_imp * 100
# Out:
# alcohol                 15.183412
# density                 12.147066
# residual sugar           8.947466
# volatile acidity         8.713091
# total sulfur dioxide     8.585341
# chlorides                8.452598
# sulphates                8.261059
# pH                       8.215577
# citric acid              7.342825
# free sulfur dioxide      7.289131
# fixed acidity            6.602441
# type                     0.259992
# dtype: float64

# %%
sns.barplot(x=feature_imp * 100, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %%
# feature type was found as 'white noise' so it won't be included un the models
X = data.drop(['quality', 'type'], axis = 1)
y = data['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5197, 11)
# (1300, 11)

# %%
k_range = list(range(1, 26))
best_roc = 0
max = 0
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
    if( roc_auc_score(y_test,y_pred) > max):
        max =  roc_auc_score(y_test,y_pred)
        best_roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred), k]

# %%
plt.plot(best_roc[0], best_roc[1], marker = '.', label = "knn prediction (knn = %0.3f)" % best_roc[2])
plt.title('ROC of knn = ' + str(best_roc[3]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of knn:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of knn:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of knn:
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      1029
#            1       0.50      0.09      0.15       271
#
#     accuracy                           0.79      1300
#    macro avg       0.65      0.53      0.52      1300
# weighted avg       0.74      0.79      0.73      1300
#
# confusion matrix of knn:
# [[1005   24]
#  [ 247   24]]

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred)]
plt.plot(roc[0], roc[1], marker = '.', label = "Random Forest prediction (knn = %0.3f)" % roc[2])
plt.title('ROC of Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of random forest:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of random forest:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of random forest:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      1029
#            1       0.79      0.58      0.67       271
#
#     accuracy                           0.88      1300
#    macro avg       0.84      0.77      0.80      1300
# weighted avg       0.87      0.88      0.87      1300
#
# confusion matrix of random forest:
# [[988  41]
#  [115 156]]

# %% [markdown]
# # using scalers to normalize the dataset

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
scaler_mm = MinMaxScaler()
scaler_s = StandardScaler()

# %%
X_mm = scaler_mm.fit_transform(X)
X_s = scaler_s.fit_transform(X)

# %%
X_mm_train, X_mm_test, y_train, y_test = train_test_split(X_mm, y, test_size=0.2, random_state=4)

# %%
k_range = list(range(1, 26))
best_roc = []
max = 0
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_mm_train, y_train)
    y_pred = knn.predict(X_mm_test)
    knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
    if( roc_auc_score(y_test,y_pred) > max):
        max =  roc_auc_score(y_test,y_pred)
        best_roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred), k]

# %%
plt.plot(best_roc[0], best_roc[1], marker = '.', label = "knn prediction (knn = %0.3f)" % best_roc[2])
plt.title('ROC of knn = ' + str(best_roc[3]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of knn:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of knn:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of knn:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1029
#            1       0.65      0.40      0.50       271
#
#     accuracy                           0.83      1300
#    macro avg       0.76      0.67      0.70      1300
# weighted avg       0.81      0.83      0.81      1300
#
# confusion matrix of knn:
# [[972  57]
#  [163 108]]

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_mm_train,y_train)
y_pred = clf.predict(X_mm_test)
knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred)]
plt.plot(roc[0], roc[1], marker = '.', label = "Random Forest prediction (knn = %0.3f)" % roc[2])
plt.title('ROC of Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of random forest:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of random forest:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of random forest:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      1029
#            1       0.81      0.57      0.67       271
#
#     accuracy                           0.88      1300
#    macro avg       0.85      0.77      0.80      1300
# weighted avg       0.88      0.88      0.87      1300
#
# confusion matrix of random forest:
# [[993  36]
#  [117 154]]

# %%
X_s_train, X_s_test, y_train, y_test = train_test_split(X_s, y, test_size=0.2, random_state=4)

# %%
k_range = list(range(1, 26))
best_roc = []
max = 0
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_s_train, y_train)
    y_pred = knn.predict(X_s_test)
    knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
    if( roc_auc_score(y_test,y_pred) > max):
        max =  roc_auc_score(y_test,y_pred)
        best_roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred), k]

# %%
plt.plot(best_roc[0], best_roc[1], marker = '.', label = "knn prediction (knn = %0.3f)" % best_roc[2])
plt.title('ROC of knn = ' + str(best_roc[3]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of knn:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of knn:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of knn:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      1029
#            1       0.65      0.40      0.50       271
#
#     accuracy                           0.83      1300
#    macro avg       0.76      0.67      0.70      1300
# weighted avg       0.81      0.83      0.81      1300
#
# confusion matrix of knn:
# [[972  57]
#  [163 108]]

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_s_train,y_train)
y_pred = clf.predict(X_s_test)
knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred)]
plt.plot(roc[0], roc[1], marker = '.', label = "Random Forest prediction (knn = %0.3f)" % roc[2])
plt.title('ROC of Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of random forest:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of random forest:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of random forest:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93      1029
#            1       0.79      0.57      0.66       271
#
#     accuracy                           0.88      1300
#    macro avg       0.84      0.76      0.79      1300
# weighted avg       0.87      0.88      0.87      1300
#
# confusion matrix of random forest:
# [[987  42]
#  [117 154]]

# %% [markdown]
# # using the oversampling method of SMOTE to imrove the dataset for the models

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
X_os_train, X_os_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
from sklearn.metrics import f1_score
k_range = list(range(1, 26))
best_roc = []
max = 0
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_os_train, y_train)
    y_pred = knn.predict(X_os_test)
    knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
    if( roc_auc_score(y_test,y_pred) > max):
        max =  roc_auc_score(y_test,y_pred)
        best_roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred), k]

# %%
plt.plot(best_roc[0], best_roc[1], marker = '.', label = "knn prediction (knn = %0.3f)" % best_roc[2])
plt.title('ROC of knn = ' + str(best_roc[3]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of knn:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of knn:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of knn:
#               precision    recall  f1-score   support
#
#            0       0.80      0.63      0.71      1588
#            1       0.69      0.83      0.75      1544
#
#     accuracy                           0.73      3132
#    macro avg       0.74      0.73      0.73      3132
# weighted avg       0.74      0.73      0.73      3132
#
# confusion matrix of knn:
# [[1008  580]
#  [ 258 1286]]

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_os_train,y_train)
y_pred = clf.predict(X_os_test)
knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred)]
plt.plot(roc[0], roc[1], marker = '.', label = "Random Forest prediction (knn = %0.3f)" % roc[2])
plt.title('ROC of Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of random forest:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of random forest:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of random forest:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.90      1588
#            1       0.88      0.94      0.91      1544
#
#     accuracy                           0.91      3132
#    macro avg       0.91      0.91      0.91      3132
# weighted avg       0.91      0.91      0.91      3132
#
# confusion matrix of random forest:
# [[1390  198]
#  [  96 1448]]

# %% [markdown]
# # using scalers to improve the data

# %%
X_mm_os = scaler_mm.fit_transform(X)
X_s_os = scaler_s.fit_transform(X)

# %%
X_os_train, X_os_test, y_train, y_test = train_test_split(X_mm_os, y, test_size=0.3, random_state=2)

# %%
plt.plot(best_roc[0], best_roc[1], marker = '.', label = "knn prediction (knn = %0.3f)" % best_roc[2])
plt.title('ROC of knn = ' + str(best_roc[3]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of knn:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of knn:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of knn:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.90      1588
#            1       0.88      0.94      0.91      1544
#
#     accuracy                           0.91      3132
#    macro avg       0.91      0.91      0.91      3132
# weighted avg       0.91      0.91      0.91      3132
#
# confusion matrix of knn:
# [[1390  198]
#  [  96 1448]]

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_os_train,y_train)
y_pred = clf.predict(X_os_test)
knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred)]
plt.plot(roc[0], roc[1], marker = '.', label = "Random Forest prediction (knn = %0.3f)" % roc[2])
plt.title('ROC of Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of random forest:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of random forest:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of random forest:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91      1588
#            1       0.89      0.94      0.91      1544
#
#     accuracy                           0.91      3132
#    macro avg       0.91      0.91      0.91      3132
# weighted avg       0.91      0.91      0.91      3132
#
# confusion matrix of random forest:
# [[1406  182]
#  [ 100 1444]]

# %%
X_os_train, X_os_test, y_train, y_test = train_test_split(X_s_os, y, test_size=0.3, random_state=2)

# %%
k_range = list(range(1, 26))
best_roc = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_os_train, y_train)
    y_pred = knn.predict(X_os_test)
    knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
    if( roc_auc_score(y_test,y_pred) > max):
        max =  roc_auc_score(y_test,y_pred)
        best_roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred), k]

# %%
plt.plot(best_roc[0], best_roc[1], marker = '.', label = "knn prediction (knn = %0.3f)" % best_roc[2])
plt.title('ROC of knn = ' + str(best_roc[3]))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of knn:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of knn:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of knn:
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76      1588
#            1       0.73      0.91      0.81      1544
#
#     accuracy                           0.79      3132
#    macro avg       0.80      0.79      0.79      3132
# weighted avg       0.81      0.79      0.78      3132
#
# confusion matrix of knn:
# [[1068  520]
#  [ 145 1399]]

# %%
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_os_train,y_train)
y_pred = clf.predict(X_os_test)
knn_fpr, knn_tpr, _ = roc_curve(y_test, y_pred)
roc = [knn_fpr, knn_tpr,  roc_auc_score(y_test,y_pred)]
plt.plot(roc[0], roc[1], marker = '.', label = "Random Forest prediction (knn = %0.3f)" % roc[2])
plt.title('ROC of Random Forest')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
print("classification report of random forest:") 
print(classification_report(y_test, y_pred))
print("confusion matrix of random forest:") 
print(confusion_matrix(y_test, y_pred))
# Out:
# classification report of random forest:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.91      1588
#            1       0.89      0.94      0.91      1544
#
#     accuracy                           0.91      3132
#    macro avg       0.91      0.91      0.91      3132
# weighted avg       0.91      0.91      0.91      3132
#
# confusion matrix of random forest:
# [[1405  183]
#  [ 100 1444]]
